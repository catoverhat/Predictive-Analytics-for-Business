# %% [markdown]
# <a href="https://colab.research.google.com/github/catoverhat/Predictive-Analytics-for-Business/blob/main/multiple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('linear-example-data.xlsx')

# %%
df.head()
# Out:
#   Client ID  Average Number of Tickets  Number of Employees  \
# 0     TK669                         90                  561
# 1     EY859                         85                  530
# 2     TN571                          5                   82
# 3     LJ675                         82                  491
# 4     KH713                         12                  230
#
#    Value of Contract       Industry
# 0             200000         Retail
# 1             200000         Retail
# 2              25000  Manufacturing
# 3             225000  Manufacturing
# 4              75000       Services

# %%
plt.scatter(df['Number of Employees'], df['Average Number of Tickets'])
plt.xlabel('Number of Employees')
plt.ylabel('Average Number of Tickets')
# Out:
# Text(0, 0.5, 'Average Number of Tickets')
